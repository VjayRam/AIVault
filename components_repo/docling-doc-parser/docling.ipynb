# %%
from docling.document_converter import DocumentConverter

source = "ReqView-SRS.pdf"  # local path or URL
converter = DocumentConverter()
result = converter.convert(source)
markdown_output = result.document.export_to_markdown()
# Out:
# c:\Users\vjayr\anaconda3\Lib\site-packages\pydantic\_internal\_fields.py:161: UserWarning: Field "model_path" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# c:\Users\vjayr\anaconda3\Lib\site-packages\pydantic\_internal\_fields.py:161: UserWarning: Field "model_spec" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# 2025-11-18 16:14:36,699 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-11-18 16:14:36,753 - INFO - Going to convert document batch...
# 2025-11-18 16:14:36,789 - INFO - Initializing pipeline for StandardPdfPipeline with options hash 44ae89a68fc272bc7889292e9b5a1bad
# 2025-11-18 16:14:36,858 - INFO - Loading plugin 'docling_defaults'
# 2025-11-18 16:14:36,866 - INFO - Registered picture descriptions: ['vlm', 'api']
# ...

# %%
# save the markdown output to a file
with open("output.md", "w") as f:
    f.write(markdown_output)

# %%
from pathlib import Path
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.base_models import InputFormat
from docling.datamodel.pipeline_options import PdfPipelineOptions

# Configure PDF pipeline options
pipeline_options = PdfPipelineOptions(
    do_ocr=True,                      # OCR for scanned docs
    do_table_structure=True,          # Table detection
    generate_picture_images=True,     # Extract images
    images_scale=2.0                  # 2x resolution
)

# Create document converter with PDF format options
converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
    }
)

# Specify your document path (can be local path or URL)
document_path = "srs_example.pdf"  # Change this to your PDF path

# Convert the document
result = converter.convert(document_path)

# Export to different formats
markdown_output = result.document.export_to_markdown()
# Out:
# 2025-11-18 16:28:57,989 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-11-18 16:28:57,997 - INFO - Going to convert document batch...
# 2025-11-18 16:28:57,998 - INFO - Initializing pipeline for StandardPdfPipeline with options hash b1813459f7b0ad9cce316a5f827accd9
# 2025-11-18 16:28:57,999 - INFO - rapidocr cannot be used because onnxruntime is not installed.
# 2025-11-18 16:28:58,000 - INFO - Accelerator device: 'cuda:0'
# 2025-11-18 16:28:59,445 - INFO - Auto OCR model selected easyocr.
# 2025-11-18 16:28:59,445 - INFO - Accelerator device: 'cuda:0'
# 2025-11-18 16:29:00,403 - INFO - Accelerator device: 'cuda:0'
# 2025-11-18 16:29:00,810 - INFO - Processing document srs_example.pdf
# 2025-11-18 16:29:38,938 - INFO - Finished converting document srs_example.pdf in 40.95 sec.

# %%
# Save as markdown
with open("document.md", "w", encoding="utf-8") as f:
    f.write(markdown_output)

print(f"\nConversion complete! Files saved to document.md")
print(f"Status: {result.status}")
# Out:
# Conversion complete! Files saved to document.md
# Status: ConversionStatus.SUCCESS
